# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import os

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %% [markdown]
# # Install ByteTrack

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()

import sys
sys.path.append(f"{HOME}/ByteTrack")

import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0

from IPython import display
display.clear_output()

import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# - Modelden gelen bounding box'ları Tracking'e aktarmak için func. tanımlıyoruz

# %%
from typing import List

import numpy as np

# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))

# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)

# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# !unzip /content/weights.zip
# Out:
# Archive:  /content/weights.zip
#    creating: content/runs/detect/train/weights/
#   inflating: content/runs/detect/train/weights/last.pt
#   inflating: content/runs/detect/train/weights/best.pt

# %%
MODEL = "content/runs/detect/train/weights/best.pt "

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs

# %% [markdown]
# ## Videonun ilk frame'ni predict edelim

# %%
CLASS_NAMES_DICT = model.model.names
CLASS_ID = [0]

CLASS_NAMES_DICT
# Out:
# {0: 'candy'}

# %%
SOURCE_VIDEO_PATH = f"{HOME}/candides.mp4"

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=2, text_thickness=1, text_scale=0.5)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# WARNING ⚠️ NMS time limit 0.550s exceeded
# 0: 480x800 13 candys, 250.6ms
# Speed: 15.5ms preprocess, 250.6ms inference, 940.3ms postprocess per image at shape (1, 3, 480, 800)

# %% [markdown]
# # Tüm videoyu predict edelim
#
# - Bir alan belirleyerek o alandan geçen detect edilmiş nesneleri sayalım

# %%
LINE_START = Point(50, 50)
LINE_END = Point(1750, 1000)

TARGET_VIDEO_PATH = f"{HOME}/candides_result.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1280, height=720, fps=30, total_frames=312)

# %%
# %%capture
from tqdm.notebook import tqdm

# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=2, text_thickness=1, text_scale=0.5)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
# 0: 480x800 13 candys, 15.7ms
# Speed: 5.5ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 5.3ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.5ms
# Speed: 9.4ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.5ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 6.8ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.7ms
# Speed: 4.5ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 16.0ms
# Speed: 5.7ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.8ms
# Speed: 4.1ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.3ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 17.1ms
# Speed: 3.8ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 5.9ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.2ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.8ms
# Speed: 4.8ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.3ms
# Speed: 4.1ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.2ms
# Speed: 3.9ms preprocess, 16.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 16.2ms
# Speed: 4.1ms preprocess, 16.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 4.3ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.5ms
# Speed: 7.6ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 13 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.7ms
# Speed: 4.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.5ms
# Speed: 4.1ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 17.1ms
# Speed: 3.6ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.5ms
# Speed: 2.7ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 19.7ms
# Speed: 6.1ms preprocess, 19.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.5ms
# Speed: 4.4ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.8ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 4.2ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.8ms
# Speed: 3.7ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.4ms
# Speed: 3.6ms preprocess, 16.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 5.0ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.7ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 5.3ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 16.6ms
# Speed: 3.5ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 6.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 6.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 6.3ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 16.0ms
# Speed: 3.6ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 16.4ms
# Speed: 3.8ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 18.0ms
# Speed: 3.9ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.5ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 candys, 15.7ms
# Speed: 4.1ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.8ms
# Speed: 3.9ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.5ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 7.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 17.1ms
# Speed: 8.3ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 4.2ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 17.7ms
# Speed: 7.4ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 6.6ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.2ms
# Speed: 3.7ms preprocess, 16.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 6.2ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 5.2ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.8ms
# Speed: 6.4ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.8ms
# Speed: 3.8ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 7.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 19.1ms
# Speed: 4.1ms preprocess, 19.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.1ms
# Speed: 6.0ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 4.3ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 6.1ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 9.9ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 4.0ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 5.2ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.4ms
# Speed: 3.8ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.8ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 16.7ms
# Speed: 3.7ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.8ms
# Speed: 3.7ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 5.3ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 2.8ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.8ms
# Speed: 3.7ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.2ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 16.1ms
# Speed: 4.4ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 17.5ms
# Speed: 4.0ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 5.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 5.2ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 2.9ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 7.2ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.2ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 4.3ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.8ms
# Speed: 6.2ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 6.2ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 5.9ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.8ms
# Speed: 2.6ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.3ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 candys, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 4.3ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 7.4ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.0ms
# Speed: 4.2ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.3ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 8.5ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 17.2ms
# Speed: 3.8ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 5.8ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 3.9ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 3.8ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.9ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 5.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.2ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 5.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 7.2ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 4.8ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 4.7ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 16.2ms
# Speed: 3.7ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 5.2ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 7.4ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 16.1ms
# Speed: 4.3ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.4ms
# Speed: 4.0ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.2ms
# Speed: 3.5ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.2ms
# Speed: 4.0ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.2ms
# Speed: 3.5ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 5.7ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.8ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 18.2ms
# Speed: 3.7ms preprocess, 18.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.6ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.2ms
# Speed: 3.7ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.2ms
# Speed: 2.7ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 16.2ms
# Speed: 3.8ms preprocess, 16.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 16.3ms
# Speed: 4.0ms preprocess, 16.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.2ms
# Speed: 3.7ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.9ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 4.2ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.9ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 4.1ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.3ms
# Speed: 8.0ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.6ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.2ms
# Speed: 4.0ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.4ms
# Speed: 4.5ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 8 candys, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 4.0ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.3ms
# Speed: 3.9ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.2ms
# Speed: 3.7ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.2ms
# Speed: 4.3ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.4ms
# Speed: 3.5ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 4.2ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.7ms
# Speed: 3.6ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.2ms
# Speed: 3.8ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.2ms
# Speed: 4.2ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 16.0ms
# Speed: 3.8ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 5.7ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.5ms
# Speed: 2.8ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.8ms
# Speed: 3.4ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 9 candys, 17.3ms
# Speed: 8.4ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.2ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.4ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.7ms
# Speed: 8.5ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.7ms
# Speed: 3.7ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 10 candys, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 12 candys, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 11 candys, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
